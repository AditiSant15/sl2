# %%
# !pip install ultralytics opencv-python matplotlib
# Out:
# Requirement already satisfied: ultralytics in .\appdata\local\programs\python\python310\lib\site-packages (8.4.39)
# Requirement already satisfied: opencv-python in .\appdata\local\programs\python\python310\lib\site-packages (4.13.0.92)
# Requirement already satisfied: matplotlib in .\appdata\local\programs\python\python310\lib\site-packages (3.10.8)
# Requirement already satisfied: numpy>=1.23.0 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: pillow>=7.1.2 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.33.1)
# Requirement already satisfied: scipy>=1.4.1 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.40.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in .\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (26.1)
# Requirement already satisfied: pyparsing>=3 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.40.0 in .\appdata\local\programs\python\python310\lib\site-packages (from polars>=0.20.0->ultralytics) (1.40.0)
# Requirement already satisfied: six>=1.5 in .\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in .\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in .\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in .\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in .\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in .\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in .\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in .\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
import sys
# !{sys.executable} -m pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.46-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: matplotlib>=3.3.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (1.17.0)
# Requirement already satisfied: torch>=1.8.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ultralytics) (7.2.1)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.40.1-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.19-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.40.1 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.40.1-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.46-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 9.2 MB/s  0:00:00
# Downloading polars-1.40.1-py3-none-any.whl (828 kB)
#    ---------------------------------------- 0.0/828.7 kB ? eta -:--:--
#    ---------------------------------------- 828.7/828.7 kB 16.8 MB/s  0:00:00
# Downloading polars_runtime_32-1.40.1-cp310-abi3-win_amd64.whl (51.8 MB)
#    ---------------------------------------- 0.0/51.8 MB ? eta -:--:--
#    ---- ----------------------------------- 6.3/51.8 MB 30.0 MB/s eta 0:00:02
#    ------ --------------------------------- 7.9/51.8 MB 19.3 MB/s eta 0:00:03
#    ------- -------------------------------- 9.2/51.8 MB 15.3 MB/s eta 0:00:03
#    -------- ------------------------------- 10.5/51.8 MB 12.9 MB/s eta 0:00:04
#    --------- ------------------------------ 11.8/51.8 MB 11.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 13.1/51.8 MB 10.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 14.2/51.8 MB 10.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 15.5/51.8 MB 9.5 MB/s eta 0:00:04
#    ------------ --------------------------- 16.8/51.8 MB 9.1 MB/s eta 0:00:04
#    ------------- -------------------------- 18.1/51.8 MB 8.8 MB/s eta 0:00:04
#    -------------- ------------------------- 19.4/51.8 MB 8.6 MB/s eta 0:00:04
#    --------------- ------------------------ 20.7/51.8 MB 8.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 22.0/51.8 MB 8.2 MB/s eta 0:00:04
#    ------------------ --------------------- 23.3/51.8 MB 8.1 MB/s eta 0:00:04
#    ------------------- -------------------- 24.6/51.8 MB 7.9 MB/s eta 0:00:04
#    ------------------- -------------------- 25.7/51.8 MB 7.8 MB/s eta 0:00:04
#    --------------------- ------------------ 27.3/51.8 MB 7.7 MB/s eta 0:00:04
#    --------------------- ------------------ 28.3/51.8 MB 7.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 29.6/51.8 MB 7.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 30.9/51.8 MB 7.5 MB/s eta 0:00:03
#    ------------------------ --------------- 32.2/51.8 MB 7.4 MB/s eta 0:00:03
#    ------------------------- -------------- 33.6/51.8 MB 7.4 MB/s eta 0:00:03
#    -------------------------- ------------- 34.3/51.8 MB 7.3 MB/s eta 0:00:03
#    --------------------------- ------------ 35.7/51.8 MB 7.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 36.7/51.8 MB 7.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 38.0/51.8 MB 7.1 MB/s eta 0:00:02
#    ------------------------------ --------- 39.3/51.8 MB 7.0 MB/s eta 0:00:02
#    ------------------------------- -------- 40.4/51.8 MB 7.0 MB/s eta 0:00:02
#    -------------------------------- ------- 41.7/51.8 MB 7.0 MB/s eta 0:00:02
#    --------------------------------- ------ 43.0/51.8 MB 7.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 44.3/51.8 MB 6.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 45.6/51.8 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------ --- 46.9/51.8 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 48.0/51.8 MB 6.9 MB/s eta 0:00:01
#    -------------------------------------- - 49.3/51.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  50.6/51.8 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  51.6/51.8 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 51.8/51.8 MB 6.7 MB/s  0:00:07
# Downloading ultralytics_thop-2.0.19-py3-none-any.whl (28 kB)
# Installing collected packages: polars-runtime-32, polars, ultralytics-thop, ultralytics
#
#    ---------------------------------------- 0/4 [polars-runtime-32]
#    ---------------------------------------- 0/4 [polars-runtime-32]
#    ---------------------------------------- 0/4 [polars-runtime-32]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    ---------- ----------------------------- 1/4 [polars]
#    -------------------- ------------------- 2/4 [ultralytics-thop]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ------------------------------ --------- 3/4 [ultralytics]
#    ---------------------------------------- 4/4 [ultralytics]
#
# Successfully installed polars-1.40.1 polars-runtime-32-1.40.1 ultralytics-8.4.46 ultralytics-thop-2.0.19
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: C:\Users\om\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO("yolov8n.pt")  # small & fast model

# %%
image_path = r"C:\Users\om\Downloads\test.webp"

img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(799.5), np.float64(532.5), np.float64(-0.5))

# %%
results = model(image_path)
# Out:
# image 1/1 C:\Users\om\Downloads\test.webp: 448x640 1 person, 1 car, 1 dog, 235.8ms
# Speed: 39.7ms preprocess, 235.8ms inference, 16.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
result_img = results[0].plot()

plt.imshow(result_img)
plt.title("Detected Objects")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(799.5), np.float64(532.5), np.float64(-0.5))

# %%
for box in results[0].boxes:
    cls = int(box.cls[0])
    print("Detected:", model.names[cls])
# Out:
# Detected: person
# Detected: car
# Detected: dog
