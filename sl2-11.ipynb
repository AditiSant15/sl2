# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras import layers, models, regularizers
#       3 from tensorflow.keras.datasets import cifar10
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0

print(f'Training data shape: {x_train.shape}')
print(f'Test data shape: {x_test.shape}')
print(f'Number of classes: {len(set(y_train.flatten()))}')

# %%
def build_model(dropout_rate=0.25, dense_units=128, learning_rate=0.001, l2_reg=0.0):
    """
    Build a CNN model for CIFAR-10 classification.
    Args:
        dropout_rate: Fraction of neurons to drop (regularization)
        dense_units: Number of neurons in the dense layer
        learning_rate: Learning rate for the Adam optimizer
        l2_reg: L2 regularization factor
    """
    model = models.Sequential([
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3), kernel_regularizer=regularizers.l2(l2_reg)),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
        layers.Flatten(),
        layers.Dense(dense_units, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
        layers.Dropout(dropout_rate),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

print('Model builder defined.')
# Out:
# Model builder defined.

# %%
print('=== Baseline Model ===')
print('Hyperparameters: dropout_rate=0.0, dense_units=512, learning_rate=0.005, l2_reg=0.0')

model_base = build_model(dropout_rate=0.0, dense_units=512, learning_rate=0.005, l2_reg=0.0)

history_base = model_base.fit(
    x_train, y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2,
    verbose=2
)
# Out:
# === Baseline Model ===
# Hyperparameters: dropout_rate=0.0, dense_units=512, learning_rate=0.005, l2_reg=0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 print('=== Baseline Model ===')
#       2 print('Hyperparameters: dropout_rate=0.0, dense_units=512, learning_rate=0.005, l2_reg=0.0')
# ----> 4 model_base = build_model(dropout_rate=0.0, dense_units=512, learning_rate=0.005, l2_reg=0.0)
#       6 history_base = model_base.fit(
#       7     x_train, y_train,
#       8     epochs=10,
#    (...)     11     verbose=2
#      12 )
#
# Cell In[2], line 10, in build_model(dropout_rate, dense_units, learning_rate, l2_reg)
#       1 def build_model(dropout_rate=0.25, dense_units=128, learning_rate=0.001, l2_reg=0.0):
#       2     """
#       3     Build a CNN model for CIFAR-10 classification.
#       4     Args:
#    (...)      8         l2_reg: L2 regularization factor
#       9     """
# ---> 10     model = models.Sequential([
#      11         layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3), kernel_regularizer=regularizers.l2(l2_reg)),
#      12         layers.MaxPooling2D((2, 2)),
#      13         layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
#      14         layers.MaxPooling2D((2, 2)),
#      15         layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
#      16         layers.Flatten(),
#      17         layers.Dense(dense_units, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
#      18         layers.Dropout(dropout_rate),
#      19         layers.Dense(10, activation='softmax')
#      20     ])
#      21     model.compile(
#      22         optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
#      23         loss='sparse_categorical_crossentropy',
#      24         metrics=['accuracy']
#      25     )
#      26     return model
#
# NameError: name 'models' is not defined

# %%
print('=== Tuned Model ===')
print('Hyperparameters: dropout_rate=0.4, dense_units=256, learning_rate=0.001, l2_reg=0.0001')

model_tuned = build_model(dropout_rate=0.4, dense_units=256, learning_rate=0.001, l2_reg=0.0001)

history_tuned = model_tuned.fit(
    x_train, y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2,
    verbose=2
)
# Out:
# === Tuned Model ===
# Hyperparameters: dropout_rate=0.4, dense_units=256, learning_rate=0.001, l2_reg=0.0001
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 print('=== Tuned Model ===')
#       2 print('Hyperparameters: dropout_rate=0.4, dense_units=256, learning_rate=0.001, l2_reg=0.0001')
# ----> 4 model_tuned = build_model(dropout_rate=0.4, dense_units=256, learning_rate=0.001, l2_reg=0.0001)
#       6 history_tuned = model_tuned.fit(
#       7     x_train, y_train,
#       8     epochs=10,
#    (...)     11     verbose=2
#      12 )
#
# Cell In[2], line 10, in build_model(dropout_rate, dense_units, learning_rate, l2_reg)
#       1 def build_model(dropout_rate=0.25, dense_units=128, learning_rate=0.001, l2_reg=0.0):
#       2     """
#       3     Build a CNN model for CIFAR-10 classification.
#       4     Args:
#    (...)      8         l2_reg: L2 regularization factor
#       9     """
# ---> 10     model = models.Sequential([
#      11         layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3), kernel_regularizer=regularizers.l2(l2_reg)),
#      12         layers.MaxPooling2D((2, 2)),
#      13         layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
#      14         layers.MaxPooling2D((2, 2)),
#      15         layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
#      16         layers.Flatten(),
#      17         layers.Dense(dense_units, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
#      18         layers.Dropout(dropout_rate),
#      19         layers.Dense(10, activation='softmax')
#      20     ])
#      21     model.compile(
#      22         optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
#      23         loss='sparse_categorical_crossentropy',
#      24         metrics=['accuracy']
#      25     )
#      26     return model
#
# NameError: name 'models' is not defined

# %%
test_loss_base, test_acc_base = model_base.evaluate(x_test, y_test, verbose=0)
test_loss_tuned, test_acc_tuned = model_tuned.evaluate(x_test, y_test, verbose=0)

print(f'Baseline Model - Test Accuracy: {test_acc_base:.4f}, Test Loss: {test_loss_base:.4f}')
print(f'Tuned Model    - Test Accuracy: {test_acc_tuned:.4f}, Test Loss: {test_loss_tuned:.4f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 test_loss_base, test_acc_base = model_base.evaluate(x_test, y_test, verbose=0)
#       2 test_loss_tuned, test_acc_tuned = model_tuned.evaluate(x_test, y_test, verbose=0)
#       4 print(f'Baseline Model - Test Accuracy: {test_acc_base:.4f}, Test Loss: {test_loss_base:.4f}')
#
# NameError: name 'model_base' is not defined

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy plot
ax1.plot(history_base.history['accuracy'], 'b--', label='Base Train Acc')
ax1.plot(history_base.history['val_accuracy'], 'r--', label='Base Val Acc')
ax1.plot(history_tuned.history['accuracy'], 'b-', label='Tuned Train Acc')
ax1.plot(history_tuned.history['val_accuracy'], 'r-', label='Tuned Val Acc')
ax1.set_title('Model Accuracy Comparison')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# Loss plot
ax2.plot(history_base.history['loss'], 'b--', label='Base Train Loss')
ax2.plot(history_base.history['val_loss'], 'r--', label='Base Val Loss')
ax2.plot(history_tuned.history['loss'], 'b-', label='Tuned Train Loss')
ax2.plot(history_tuned.history['val_loss'], 'r-', label='Tuned Val Loss')
ax2.set_title('Model Loss Comparison')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
#       3 # Accuracy plot
#       4 ax1.plot(history_base.history['accuracy'], 'b--', label='Base Train Acc')
#
# NameError: name 'plt' is not defined

# %%
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

y_pred_tuned = np.argmax(model_tuned.predict(x_test, verbose=0), axis=1)
y_true = y_test.flatten()

fig, axes = plt.subplots(2, 5, figsize=(12, 6))
for i in range(10):
    idx = np.random.randint(0, len(x_test))
    ax = axes[i//5, i%5]
    ax.imshow(x_test[idx])
    predicted_class = class_names[y_pred_tuned[idx]]
    actual_class = class_names[y_true[idx]]
    color = 'green' if y_pred_tuned[idx] == y_true[idx] else 'red'
    ax.set_title(f'Pred: {predicted_class}\nActual: {actual_class}', color=color, fontweight='bold', fontsize=8)
    ax.axis('off')
plt.suptitle('Tuned Model: Predictions on Test Images', fontweight='bold', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
# ----> 3 y_pred_tuned = np.argmax(model_tuned.predict(x_test, verbose=0), axis=1)
#       4 y_true = y_test.flatten()
#       6 fig, axes = plt.subplots(2, 5, figsize=(12, 6))
#
# NameError: name 'np' is not defined
